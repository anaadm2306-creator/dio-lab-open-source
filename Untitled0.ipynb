# %% [markdown]
# <a href="https://colab.research.google.com/github/anaadm2306-creator/dio-lab-open-source/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalando as ferramentas de IA e o motor de troca de rosto
# !pip install -q diffusers transformers accelerate onnxruntime-gpu
# !pip install -q insightface==0.7.3  # Versão específica para estabilidade
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.8/252.8 MB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.5/439.5 kB 13.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 102.2 MB/s eta 0:00:00
# ...

# %%
# Criar a pasta de modelos do InsightFace
# !mkdir -p /root/.insightface/models/

# Baixar o modelo de troca de rosto (inswriter) de um servidor reserva
# !wget -O /root/.insightface/models/inswriter_on_nx.onnx https://github.com/facefusion/facefusion-assets/releases/download/models/inswriter_on_nx.onnx

print("✅ Modelo baixado com sucesso!")
# Out:
# --2026-04-02 16:10:44--  https://github.com/facefusion/facefusion-assets/releases/download/models/inswriter_on_nx.onnx
# Resolving github.com (github.com)... 140.82.116.3
# Connecting to github.com (github.com)|140.82.116.3|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2026-04-02 16:10:45 ERROR 404: Not Found.
#
# ✅ Modelo baixado com sucesso!
